# %% [markdown]
# ### 預備
#
# - 執行程式需要有PyPDF2模組

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#      - -------------------------------------- 10.2/232.6 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/232.6 kB 325.1 kB/s eta 0:00:01
#      ------ ------------------------------ 41.0/232.6 kB 326.8 kB/s eta 0:00:01
#      ----------------- ------------------ 112.6/232.6 kB 656.4 kB/s eta 0:00:01
#      ------------------------------------ - 225.3/232.6 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 232.6/232.6 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %% [markdown]
# - 這些程式碼為geeks[網友們](https://www.geeksforgeeks.org/working-with-pdf-files-in-python/)所建議的。
# - 把檔名改成個案報告
# - 中文檔名有點複雜，注意必須用雙引號。冒號、空格、反斜線、括號等等，在window Anaconda3的Jypyter環境下，都不必另外加上反斜線。

# %%
import PyPDF2
 
# creating a pdf file object
pdfFileObj = open("D:\E\My Documents\EIAs\電廠\GAS_EIA\(1070401A) 興達電廠燃氣機組更新改建計畫環境影響說明書\C07.pdf", 'rb')
 
# creating a pdf reader object
pdfReader = PyPDF2.PdfReader(pdfFileObj)
 
# printing number of pages in pdf file
print(len(pdfReader.pages))
 
# creating a page object
pageObj = pdfReader.pages[0]
 
# extracting text from page
print(pageObj.extract_text())
 
# closing the pdf file object
#pdfFileObj.close()
# Out:
# 168
# 興達電廠燃氣 機組更新改建計畫環境影響說明書                                           第七章
# 台灣電力公司
# 7-1 第七章  預測開發行為可能引起之環境影響
# 7.1  物理及化學環境
# 7.1.1 地形及地質
# 依據本計畫調查 結果，興達電廠燃氣機組預定地皆 為平坦濕地，開發行為
# 應不致對地形造成影響。
# 參閱中央地質調查所公布之台南以及高雄初級土壤液化潛勢圖，本案工址
# 所在之高雄市永安區屬高雄市土 壤液化潛勢分析第二期計畫，尚未有公開之液
# 化資訊。故依「興達燃氣機組更新改建計畫可研地質鑽探報告書 (106年1月)」，
# 彙整出液化潛能分析結果，地表最大水平加速度為 0.076g 時，燃氣機組預定地
# 屬輕微液化程度，天然氣管線預定路線之液化危險 度極低；但當地表最大水平
# 加速度達 0.320g 以上，燃氣機組預定地及天然氣管線預定路線皆屬嚴重液化程
# 度，分析資料詳見 附錄 26.6(附件 2)。
# 本廠址地層地表下至 20米範圍內屬灰色粉土質黏土夾砂質粉土 (N=1~7)，
# 部分地層可能有液化之顧慮且具沉陷機制，此地層於超額載重作用下，其基礎
# 沉陷量大。目前 細部設計階段正辦理細部地質鑽探與土壤試驗作業，未來將依
# 試驗成果考量載重，並依相關設計規範進行地質改良與基礎設計。
# 考量上述分析結果，一般可於工程設計採行之因應對策內容摘述如下：
# 1.土壤改良：化學固結工法 (深層攪拌工法、特殊石灰樁 )，以及排水工法 (真
# 空壓密工法、礫石樁、排水帶 )。
# 2.基礎型式選擇或處理：樁基礎、基礎版下砂礫層、地下圍牆基礎。
# 3.管線型式選擇：可撓管、耐震伸縮材料。
# 7.1.2 斷層及地震
# 一、地震
# 本計畫周圍之地震活動，主要 分布於北方臺南市區域及西方外海一
# 帶，距離超過 15公里。自 1973~2017 年5月間，計畫區域半徑 50公里範
# 圍內共發生 41,460次地震，單位面積發生地震次數比約為 12次/年/100平
# 方公里，遠低於全臺平均 (74次/年/100平方公里 )。在這 41,460次地震事
# 件中，多屬於規模小於 3之微震 (39,084次)；規模介於 3至5之間的地震
# 有2,346次，而規模 5以上可能造成危害之地震僅有 30次發生紀錄，平均

# %% [markdown]
# ### 讀出標題
# - 先將所有內容按照跳行指令將其切割成一行行文字的序列
# - 每行的前導文字是否含有標題編號，如是，則挑出成為outlines
# - 沒有妥善命名的標題、只是用編號來寫一段段的文字內容，此處還是將其視為標題，以60字為限。希望前面幾個字能出現重點(要靠語言模型了)。

# %%
a=''
i=1
for pageObj in pdfReader.pages:
    a+=pageObj.extract_text().replace('7-'+str(i)+' ','')
    i+=1
lines=a.split('\n')
outlines=[l.split(':')[0].split('：')[0].strip() for l in lines]
outlines=[l for l in outlines if (dots(l) or CNnum(l) or ENnum(l))  and len(l)<60]
outlines=[l for l in outlines if '-' not in l]
for i in outlines[:30]:
    print(i)
# Out:
# 7.1  物理及化學環境
# 7.1.1 地形及地質
# 1.土壤改良
# 2.基礎型式選擇或處理
# 3.管線型式選擇
# 7.1.2 斷層及地震
# 一、地震
# 二、斷層
# 7.1.3 土壤
# 一、施工期間
# 二、營運期間
# 7.1.4 空氣品質
# 一、空氣品質模擬
# (一)施工期間
# 1.評估條件
# 2.影響分析
# (1)氣狀污染物 (SO 2、NO 2、CO)
# (2)粒狀污染物 (TSP、PM 10、PM 2.5).
# (3)運輸道路路緣影響分析
# 2.TSP背景濃度為民國 106年本電廠周邊環境監測結果最大值。
# 2.TSP背景濃度為民國 106年本電廠周邊環境監測結果最大值。
# (二)營運期間
# 1.本計畫燃氣機組排放量
# (1)興達電廠全廠空污排放量計算
# 2.考量未來持續成長之電力需求，在符合排放標準及空污總量管制前提下，將既有廠區做整體性規劃，以充分最佳化利用空間。
# 3.既有廠區於機組除役後的削減總量差額，將依總 量管制保留抵換辦法規定申請保留，視未來電力供應需求使用。
# 4.依據台灣中油公司 之天然氣最大含硫量規範，硫氧化物濃度 推估為 0.8 ppm。
# 5.107年後之燃煤機組空污排放量計算係以生煤許可量進行估算，並已考量空污改善效益。
# (C) 全廠排
# (A) 燃氣

# %% [markdown]
# - 這支副程式在確認前導的文字是否含有1.、(1)、（1）等等情況。

# %%
def dots(l):
    tdic={'':'.','(':')','（':'）'}
    for p in ['','(','(']:
        for i in range(1,11):
            a=p+str(i)+tdic[p]
            n=len(a)
            if l[:n]==a:return True
    return False

# %% [markdown]
# - 這2組副程式的邏輯是一樣的，除了中間的英數字之外，前後括弧也是比對的重點。

# %%
def CNnum(l):
    num=['一','二','三','四','五','六','七','八','九','十',]
    tdic={'':'、','(':')','（':'）'}
    for p in ['','(','(']:
        for i in num:
            a=p+i+tdic[p]
            n=len(a)
            if l[:n]==a:return True
    return False

# %%
def ENnum(l):
    num='ABCDEFGHabcdefgh'
    tdic={'':'.','(':')','（':'）'}
    for p in ['','(']:
        for i in num:
            t=''
            if p in [' ','']:t='.'
            a=p+i+tdic[p]
            n=len(a)
            if l[:n]==a:return True
    return False

# %%
pdfReader.pages[76].extract_text().split('\n')
# Out:
# ['第七章  預測開發行為可能引起之環境影響  ',
#  '7 - 76 ',
#  ' 大型車  施工車輛  (10 輛/日)÷7 小時 /日≒1 輛/小時 *2 PCU/車次 (單向 ) =2 ',
#  'PCU/小時 (單向 )  ',
#  '一般時段尖峰交通量： 3 PCU + 2 PCU + 2 PCU = 7 PCU/小時 (單向 ) ',
#  'B.上、下班時段 (07:00~08:00 與17:00~18:00)  ',
#  '機車  45 輛/日÷1 小時 /日=45 輛/小時 (單向 ) *0.5 PCU/ 車次 (單向 )  ',
#  '=23 PCU/ 小時 (單向 )  ',
#  '小型車  60 輛/日÷1 小時 /日=60 輛/小時 (單向 ) *1 PCU/ 車次 (單向 )  ',
#  '=60 PCU/ 小時 (單向 ) ',
#  '大客車  1 輛/日÷1 小時 /日≒1 輛/小時 *2 PCU/車次 (單向 )  ',
#  '=2 PCU/小時 (單向 ) ',
#  '上、下班時段交通量： 23 PCU+60 PCU+2 PCU =85 PCU/ 小時 (單向 ) ',
#  'C.施工期間每日尖峰小時交通量，將考慮以上交通增量，以影響最大之車流量',
#  '評估本計畫附近各道路之影響。  ',
#  '(2)衍生交通量路網指派  ',
#  '前述衍生之交通量參考台中電廠於 109年2月「台中發電廠新建燃氣機組計',
#  '畫」環境影響說明書 (定稿本 )中交通量指派方式，採約有 60%北向聯絡清水、',
#  '梧棲、沙鹿及鄰近之臺中都會區，約有 40%往南聯絡龍井、大肚及彰化濱海',
#  '地區。  ',
#  '(3) 考量基地周邊鄰近相關計畫交通增量  ',
#  '本基地周邊 主要有「 台中發電廠新建燃氣機組計畫」 以及「台中廠第三期投資',
#  '計畫 (增建儲槽及相關附屬設施 )」等。保守假設該 2處計畫施工期間與本計畫',
#  '重疊，經查 109年2月「台中發電廠新建燃氣機組計畫」 環境影響說明書 (定',
#  '稿本 )所載，預估主要施工時段 (8:00~17:00 ，中間 12:00~13:00 休息 )每小時衍',
#  '生交通量為 36 PCU(單向 );通勤時段每小時衍生交通量為 593 PCU(單向 )。另',
#  '查110年1月「台中廠第三期投資計畫 (增建儲槽及相關附屬設施 )」環境影響',
#  '說明書 (定稿本 )所載，預估主要施工時段 (9:00~17:00) 每小時衍生交通量為 6 ',
#  'PCU(單向 );尖峰通勤時段每小時衍生交通量為 151 PCU(單向 )，將納入本計畫',
#  '施工期間交通增量。  ',
#  '故本計畫考量鄰近相關計畫開發增量後，施工時段累計最大 衍生交通量推估',
#  '如下： 7 PCU +36 PCU  +6 PCU = 49 PCU/小時 (單向 )，另通勤 時段累計最大 衍',
#  '生交通量推估如下： 85 PCU +593  PCU  +151  PCU = 829 PCU/小時 (單向 )，並',
#  '以影響最大之交通量 (累計施工期間尖峰小時通勤交通量為 829 PCU) 做為評',
#  '估本計畫施工期間附近各道路之 交通影響增量。 ',
#  '  ']

# %%
p=3
outlines[30*p:30*(p+1)]
l='3. 機組排放率資料  '
len(l)<60
# Out:
# True

# %% [markdown]
# ### 另寫成可執行的程式
#
# - 讓引數控制輸入檔案
# - 大潭電廠的pdf檔是掃描檔，PyPDF2無法閱讀，先暫時擱置。
# - 執行結果會在每個pdf檔案所在目錄產生一個outline.txt。
#     - 這個檔案還需要進一步人工檢視
#     - 檢視重點：是否為表格、圖片的文字內容、是否是某個段落中的文字、計算式等等情況
#     - 另存新檔outlineR.txt

# %%
run pp.py 4

# %% [markdown]
# ### 開啟標題檔
# - 開啟文字檔
# - 儲存成pandas的工作表

# %%
from pandas import *
fname="D:\E\My Documents\EIAs\電廠\GAS_EIA\(1070401A) 興達電廠燃氣機組更新改建計畫環境影響說明書\C07outlineR.txt"
with open(fname,'r') as f:
    lines=[l.strip().replace('\n','') for l in f]
df=DataFrame({'tit':lines,'lev':0})

# %% [markdown]
# - 按照標題前的數字(文字)編號，辨識其階層。以便讓後續層級間關係認定會更好操作。
# - 因第1與第2層太相像，先解決第2層，在給定第1層，這樣的邏輯較為容易。

# %%
chnum=['一','二','三','四','五','六','七','八','九','十',]
df['id']=df.index
df.loc[df.tit.map(lambda x:x.count('.')==2 and x[0].isdigit() and x[2].isdigit() and x[4].isdigit()),'lev']=2
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[2].isdigit() and x[1]=='.')),'lev']=1
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[0] in chnum)),'lev']=3
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[1] in chnum)),'lev']=4
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[0].isdigit())),'lev']=5
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[1].isdigit() and x[0]=='(' and x[2]==')')),'lev']=6
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[0].isupper())),'lev']=7
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[1].isupper() and x[0]=='(' and x[2]==')')),'lev']=8
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[0].islower())),'lev']=9
df.loc[(df.lev==0)&(df.tit.map(lambda x:x[1].islower() and x[0]=='(' and x[2]==')')),'lev']=10

# %% [markdown]
# 插播一下。chatGPT有給出程式建議，但似乎不能作用在複雜的情況。嘗試失敗，只能自救。

# %%
df['parent_id'] = None
for index, row in df.iterrows():
    if row['lev'] > 0:
        parent_row = df.loc[df['id'] == row['id'] - 1]
        if not parent_row.empty:
            df.at[index, 'parent_id'] = parent_row['id'].values[0]
df
# Out:
#                                  tit  lev   id parent_id
# 0                       7.1  物理及化學環境    0    0      None
# 1                        7.1.1 地形及地質    1    1         0
# 2                             1.土壤改良    4    2         1
# 3                        2.基礎型式選擇或處理    4    3         2
# 4                           3.管線型式選擇    4    4         3
# ..                               ...  ...  ...       ...
# 256                   1.第一個條件是有漏氣現象；    4  256       255
# 257  2.第二個條件是漏出氣體被收集於密閉物體或場所中，無法溢散至大    4  257       256
# 258  3.第三個條件是有火花產生，因而造成火災或爆炸，或人員進入高濃    4  258       257
# 259                       (二) 減輕影響說明    3  259       258
# 260                       7.8 健康風險評估    0  260      None
#
# [261 rows x 4 columns]

# %% [markdown]
# 最後的程式寫成這樣。雖然比較笨、但還蠻管用的。解釋一下:
# - `mnlev,mxlev`是階層的最高和最低層(數字小的是高層)。這樣寫可以適用在所有情況，也不限定一定要從0開始。
# - 每一(母)層先從df中篩出來(`a`)，因為outline是按照順序的，所以`a`注標之間就是該段的範圍。做出起訖注標(`ai,aj`)邏輯就更清楚。
# - 子層(`b`)的定義。考量到很多同仁並不按照階層規範逐一編寫，會有跳層的情形，所以此處篩出凡是階層數低於`a`、且尚未給定從屬關係(`df.parent_id`)的內容。
# - 按照前述起訖注標(`ai,aj`)分段篩選子層(`b`)，挑出當中的最高層，將其與母層進行連結，就是將`df.parent_id`令為`ai[i]`。

# %%
df['parent_id'] = None
mnlev,mxlev=df.lev.min(),df.lev.max()
for l in range(mnlev,mxlev):
    a=df.loc[df.lev==l]
    n=len(a)
    if n==0:continue
    ai=list(a.index)
    aj=ai[1:]+[len(df)]
    b=df.loc[(df.lev>l) & (df.parent_id.isnull())] 
    for i in range(n):
        boo=(b.index>ai[i]) & (b.index<aj[i] )
        c=b.loc[boo]
        mn=c.lev.min()
        df.loc[c.loc[c.lev==mn].index,'parent_id']=ai[i]

# %% [markdown]
# 寫成csv檔案以備下一階段使用。

# %%
fname=fname.replace('outlineR.txt','.csv')
df.set_index('id').to_csv(fname)

# %%
df.loc[(df.lev==1)]
# Out:
#                            tit  lev   id parent_id
# 1                  7.1.1 地形及地質    1    1         0
# 5                  7.1.2 斷層及地震    1    5         0
# 8                     7.1.3 土壤    1    8         0
# 11                  7.1.4 空氣品質    1   11         0
# 63                 7.1.5 噪音與振動    1   63         0
# 97                  7.1.6 水文水質    1   97         0
# 109                 7.1.7 海域水質    1  109         0
# 112                  7.1.8 廢棄物    1  112         0
# 126                 7.3.1 陸域植物    1  126       125
# 133                 7.3.2 陸域動物    1  133       125
# 157                 7.3.3 水域生態    1  157       125
# 158                 7.3.4 海域生態    1  158       125
# 161           7.3.5 電廠歷年監測數據分析    1  161       125
# 164  7.3.6 電廠汲入海水 造成當地漁業資源損失評估    1  164       125
# 174   7.4.1  開發行為景觀現況美質影響調查與評估    1  174       173
# 182                 7.4.2 遊憩環境    1  182       173
# 203             7.4.3 概念設計國際競圖    1  203       173
# 205                 7.5.1 土地利用    1  205       204
# 208                 7.5.2 人口特性    1  208       204
# 211            7.5.3 就業機會與產業結構    1  211       204
# 214              7.5.4 公共設施 服務    1  214       204
# 217                 7.5.5 交通運輸    1  217       204
# 234  7.5.6  應用熱電共生系統供應區域冷熱需求評估    1  234       204

# %% [markdown]
# 寫成單獨執行的程式，可以處理別的個案。

# %%
run level.py 2

# %%
df.iloc[:60]
# Out:
#                                              tit  lev  id parent_id
# 0                                      7.1  物化環境    1   0      None
# 1                                   7.1.1  地形及地質    2   1         0
# 2                                   一、  地層液化潛能分析    3   2         1
# 3                                      (一) 中小度地震    4   3         2
# 4                                       (二) 設計地震    4   4         2
# 5                                二、  基礎承載力與沉陷量分析    3   5         1
# 6                                    7.1.2  空氣品質    2   6         0
# 7                                       一、  施工期間    3   7         6
# 8                                       (一) 評估條件    4   8         7
# 9                                       (二) 影響分析    4   9         7
# 10                       1. 氣狀污染物 (SO 2、NO 2、CO)    5  10         9
# 11                   2. 粒狀污染物 (TSP、PM 10、PM 2.5)    5  11         9
# 12                                 3. 運輸道路路緣影響分析    5  12         9
# 13                                      二、  營運期間    3  13         6
# 14                                      (一) 評估條件    4  14        13
# 15                                     1. 排放標準分析    5  15        14
# 16                                2. 空污法第六條及子法分析    5  16        14
# 17                                3. 本計畫燃氣機組排放 量    5  17        14
# 18                                      (二) 影響分析    4  18        13
# 19                               1. 原生性空氣污染物影響分析    5  19        18
# 20                         (1) 氣狀污染物（ SO 2、NO 2）    6  20        19
# 21                  (2) 粒狀污染物（ TSP、PM 10、PM 2.5）    6  21        19
# 22                                (3) 運輸道路路緣影響分析    6  22        19
# 23                               2. 衍生性空氣污染物影響分析    5  23        18
# 24                                 (1) 模式設定及輸入資料    6  24        23
# 25                                        A.使用模式    7  25        24
# 26                                      B.模擬案例選擇    7  26        24
# 27                                  C.模擬範圍與網格解析度    7  27        24
# 28                                        D.氣象資料    7  28        24
# 29                                   E.邊界條件與初始條件    7  29        24
# 30                                       F.排放量資料    7  30        24
# 31                                     (a)背景排放資料   10  31        30
# 32                                   (b)本計畫新增排放量   10  32        30
# 33                             (2) 背景模擬結果與模式性能評估    6  33        23
# 34                                  (3) 臭氧增量評估結果    6  34        23
# 35                        (4) PM 10及PM 2.5增量評估結果    6  35        23
# 36                            (三) 台中發電廠 空污排放總量分析    4  36        13
# 37                      1. 環保署電力設施標準加嚴對既有燃煤機組之影響    5  37        36
# 38                                  2. 生煤管制條例之影響    5  38        36
# 39                           (四) 台中發電廠 全廠減排 規劃方案    4  39        13
# 40                      1. 新燃氣機組運轉後， 部份燃煤機組 轉為備用    5  40        39
# 41        (1) 當環保署空氣品質監測網 每日上午預報隔日中部空品區 AQI>100時    6  41        40
# 42         (2) 當環保署空氣品質監測網 每日上午預報隔日中部空品區 AQI≦100    6  42        40
# 43             A. 不含備用機組之預估備轉容量率 <8%時，啟動 1部備用機組。    7  43        42
# 44           B. 若啟動 1部備用機組 後，預估備轉容量率仍 <8%時，啟動第2部    7  44        42
# 45              C. 2部新燃氣機組運轉後，最多啟動 2部備用燃煤機組，且啟動燃    7  45        42
# 46                        (1) 108-112年(燃氣機組運轉前 )    6  46        40
# 47                             (2) 113年(1部燃氣運轉 )    6  47        40
# 48                                       A. 最劣情境    7  48        47
# 49                                       B. 常態情境    7  49        47
# 50                            (3) 114年起(2部燃氣運轉 )    6  50        40
# 51                                       A. 最劣情境    7  51        50
# 52                                       B. 常態情境    7  52        50
# 53                               (4) 備用機組運轉及調度機制    6  53        40
# 54                                 2. 既有燃煤機組排放改善    5  54        39
# 55                              3. 全廠空污排放減量 推估設定    5  55        39
# 56                           4. 燃煤機組空氣污染物排放量估算說明    5  56        39
# 57           (1) 以台中電廠 107年既有燃煤機組之排放情境為基準，包括各污染物    6  57        56
# 58  (2) 依各年度 (108 -114年)設定之運轉情境 (非空品不良季 最多 9部燃煤、    6  58        56
# 59                                 (3) 計算排放濃度削減率    6  59        56

# %%
df.iloc[60:120]
# Out:
#                                                  tit  lev   id parent_id
# 60             (4) 既有燃煤機組之排放量 (C)=情境排放量 (A)－削減量 (B)。    6   60        56
# 61                                  5. 全廠空污 排放減量效益推估    5   61        39
# 62                             (1) 107-114年全廠逐年排放量變化    6   62        61
# 63                                           A. 最劣情境    7   63        62
# 64                                           B. 常態情境    7   64        62
# 65                                C. 最劣及常態情境推估結果綜合說明    7   65        62
# 66                                  6. 空氣品質改善效益與模擬結果    5   66        39
# 67                                       7.1.3  溫室氣體    2   67         0
# 68                                一、  施工期間 溫室氣體排放量推估    3   68        67
# 69                                          (一) 施工機具    4   69        68
# 70                                           (二) 化糞池    4   70        68
# 71                                          (三) 電力使用    4   71        68
# 72                                二、  營運期間 溫室氣體排放量推估    3   72        67
# 73           (一) 依據台灣中油股份有限公司天然氣事業部之物質安全資料表天然氣 (2)，天    4   73        72
# 74           (二) 依據台中發電廠新建燃氣機組計畫可行性研究報告，天然氣熱值 (LHV)為    4   74        72
# 75   (三) 全球溫暖化潛勢 (Global Warming Potential, GWP) 分別為    4   75        72
# 76                                     三、  本計畫節能減碳規劃    3   76        67
# 77              (一) 優先選用高效率轉動設備、高效率驅動控制設備等附屬設備，以及其他節    4   77        76
# 78           (二) 規劃於燃氣機組行 政大樓與主控制大樓屋頂設置屋頂型 太陽光電設施， 其    4   78        76
# 79            (三) 燃氣機組新建行政大樓 採用綠建築設計 概念，導入建築通風節能、隔熱節    4   79        76
# 80           (四) 電廠公務 機車優先選購電動 機車，宣導廠區內活動儘量步行或以自行車 代    4   80        76
# 81              (五) 未來配合產業需求及冷能利用產業化，於接收站場址內規劃冷能產業發展    4   81        76
# 82                                       7.1.4  噪音振動    2   82         0
# 83                                            一、  噪音    3   83        82
# 84                                      (一) 噪音主要影響區位    4   84        83
# 85                                      (二) 噪音影響評估基準    4   85        83
# 86                                      (三) 噪音評估模式說明    4   86        83
# 87                                    (四) 施工期間噪音影響預測    4   87        83
# 88                                1. 工作面施工機具作業時產生之噪音    5   88        87
# 89                                      2. 鄰近受體點施工音量    5   89        87
# 90                                  3. 運輸車輛作業產生之噪音影響    5   90        87
# 91                                    (五) 營運期間噪音影響預測    4   91        83
# 92                                     1. 鄰近受體點之噪音影響    5   92        91
# 93                                         2. 道路交通噪音    5   93        91
# 94                                           3. 低頻噪音    5   94        91
# 95                                            二、  振動    3   95        82
# 96                                      (一) 振動主要影響區位    4   96        95
# 97                                      (二) 振動影響評估基準    4   97        95
# 98                                       (三) 本計畫振動來源    4   98        95
# 99                                        (四) 振動影響預測    4   99        95
# 100                                        1. 施工期間振動    5  100        99
# 101                                       (1) 施工機具振動    6  101       100
# 102                                     (2) 施工運輸車輛振動    6  102       100
# 103                                        2. 營運期間振動    5  103        99
# 104                                        7.1.5  水質    2  104         0
# 105                                         一、  施工期間    3  105       104
# 106                                     (一) 營建工地逕流廢水    4  106       105
# 107                                     1. 土壤沖蝕指數 Km    5  107       106
# 108                                             2. L    5  108       106
# 109                                        3. S︰坡度因子    5  109       106
# 110                                     4. 覆蓋與管理因子 C    5  110       106
# 111                                    5. 水土保持處理因子 P    5  111       106
# 112                                   (二) 施工人員生活污水處理    4  112       105
# 113                                         二、  營運期間    3  113       104
# 114                                         (一) 生活污水    4  114       113
# 115                                   1. 新建燃氣機組 廠區部分    5  115       114
# 116                                 2. 液化天然氣接收站場區 部分    5  116       114
# 117                                         (二) 製程廢水    4  117       113
# 118                                          三、  溫排水    3  118       104
# 119                                         (一) 排放條件    4  119       118

# %%
df.iloc[120:180]
# Out:
#                             tit  lev   id parent_id
# 120               (二) 溫排水溫升模擬評估    4  120       118
# 121                     1. 模擬條件    5  121       120
# 122                     2. 模擬成果    5  122       120
# 123             3. 模擬成果與實測值比對分析    5  123       120
# 124                  7.1.6  廢棄物    2  124         0
# 125                    一、  施工期間    3  125       124
# 126                    (一) 工程廢料    4  126       125
# 127               (二) 施工人員生活廢棄物    4  127       125
# 128                    二、  營運期間    3  128       124
# 129                   (一) 事業廢棄物    4  129       128
# 130                   (二) 生活廢棄物    4  130       128
# 131               7.1.7  剩餘土石 方    2  131         0
# 132             一、  臺中港其他工程塡地利用    3  132       131
# 133                二、  土方外運填地利用    3  133       131
# 134            三、  合法土石方資源堆置處理場    3  134       131
# 135                   7.2  生態環境    1  135      None
# 136               7.2.1  陸域動物生態    2  136       135
# 137               7.2.2  陸域植物生態    2  137       135
# 138                 7.2.3  水域生態    2  138       135
# 139                 7.2.4  海域生態    2  139       135
# 140            一、  施工期間對海域生態之影響    3  140       139
# 141  二、  營運期間 污水處理廠放 流水對海域生態之影響    3  141       139
# 142      三、  營運期間溫 排水排放對海域生態之影響    3  142       139
# 143                 (一) 植物性浮游生物    4  143       142
# 144                 (二) 動物性浮游生物    4  144       142
# 145                  (三) 海域底棲生物    4  145       142
# 146                   (四) 海洋哺乳類    4  146       142
# 147                四、  落淤生態影響分析    3  147       139
# 148             7.2.5  海洋生態系統價值    2  148       135
# 149   一、海水汲取 (含撞擊 )之海域生態影響 差異分析    3  149       148
# 150                (一)海水汲入量差異分析    4  150       149
# 151                 1.台中發電廠運轉現況    5  151       150
# 152                 2.未來目標年運轉情境    5  152       150
# 153                   3.海水汲入量差異    5  153       150
# 154                 (二)海域生態影響評估    4  154       149
# 155       1.海水汲入量減少對海域生態影響之差異分析    5  155       154
# 156                  (1)植物性浮游生物    6  156       155
# 157                  (2)動物性浮游生物    6  157       155
# 158                     (3)底棲生物    6  158       155
# 159                       (4)魚卵    6  159       155
# 160                      (5)仔稚魚    6  160       155
# 161                2.成魚撞擊濾網損失評估    5  161       154
# 162  (三)運轉現況及未來目標年之 海域生態影響 損失比較    4  162       149
# 163                 二、海域排放之生態影響    3  163       148
# 164                  (一)溫排水排放影響    4  164       163
# 165        1.台中發電廠運 轉現況影響範圍之水體積    5  165       164
# 166         2.未來目標年運轉情境影響範圍之水體積    5  166       164
# 167   3. 溫升影響水體積減少對海域生態影響之 差異分析    5  167       164
# 168                  (1)植物性浮游生物    6  168       167
# 169                  (2)動物性浮游生物    6  169       167
# 170                     (3)底棲生物    6  170       167
# 171                       (4)魚卵    6  171       167
# 172                      (5)仔稚魚    6  172       167
# 173   4.運轉現況及未來目標年之 海域生態影響 損失比較    5  173       164
# 174                三、漁業資源損失差異分析    3  174       148
# 175                    1.魚卵及仔稚魚    5  175       174
# 176          2.撞擊濾網生物量 (含魚蝦蟹貝 )    5  176       174
# 177      3.台中電廠現況及未來目標年漁貨價值損失比較    5  177       174
# 178                 7.3  景觀遊憩環境    1  178      None
# 179             7.3.1  景觀模擬影響評估    2  179       178

# %%
df.iloc[180:240]
# Out:
#                                     tit  lev   id parent_id
# 180                        一、  視覺影響範圍調查    3  180       179
# 181                         二、  景觀控制點選取    3  181       179
# 182                          三、  景觀美質分析    3  182       179
# 183                     四、  觀景點視覺影響模擬評估    3  183       179
# 184                          (一) 開發行為模擬    4  184       183
# 185                          (二) 景觀影響預測    4  185       183
# 186                         7.3.2  遊憩環境    2  186       178
# 187                        一、  開發行為影響預測    3  187       186
# 188                     (一) 施工期間的遊憩影響預測    4  188       187
# 189                     1. 遊憩據點的交通可及性影響    5  189       188
# 190                    2. 鄰近遊憩據點的遊憩體驗影響    5  190       188
# 191                     (二) 營運期間的遊憩影響預測    4  191       187
# 192             1. 燃氣機組及 液化天然氣 接收站之視覺影響    5  192       191
# 193                     2. 遊憩景點之交通可及性影響    5  193       191
# 194                    二、  可能影響遊憩點預測與評估    3  194       186
# 195                         (一) 高美濕地風景區    4  195       194
# 196                          (二) 梧棲觀光漁港    4  196       194
# 197                     (三) 大肚溪口野生動物保護區    4  197       194
# 198                          (四) 麗水河濱公園    4  198       194
# 199                        (五) 臺中港區藝術中心    4  199       194
# 200                           (六) 清水遊憩區    4  200       194
# 201                        三、  遊憩影響綜合評估    3  201       186
# 202                           1.高美濕地風景區    5  202       201
# 203                            2.梧棲觀光漁港    5  203       201
# 204                          3.大肚溪口野生動物    5  204       201
# 205                            4.麗水河濱公園    5  205       201
# 206                          5.臺中港區藝術中心    5  206       201
# 207                             6.清水遊憩區    5  207       201
# 208                           7.4  社會經濟    1  208      None
# 209                         7.4.1  人口特性    2  209       208
# 210                            一、  施工期間    3  210       209
# 211                            二、  運轉期間    3  211       209
# 212                    7.4.2  就業機會及產業結構    2  212       208
# 213                            一、  就業機會    3  213       212
# 214                            (一) 施工期間    4  214       213
# 215       1. 台電公司聘僱人員，即台電公司的技術人員及管理人員等。    5  215       214
# 216           2. 包商人員，即承包各項工程之包商所轄工作人員。    5  216       214
# 217  3. 支援人力，即支援台電公司之外包人員，包括技術性及非技術性人員。    5  217       214
# 218                            (二) 運轉期間    4  218       213
# 219                            二、  經濟活動    3  219       212
# 220                            (一) 施工期間    4  220       219
# 221                            (二) 運轉期間    4  221       219
# 222                              三、  地價    3  222       212
# 223                            四、  生活水準    3  223       212
# 224                         7.4.3  土地利用    2  224       208
# 225                         7.4.4  公共設施    2  225       208
# 226                            一、  施工期間    3  226       225
# 227                            二、  運轉期間    3  227       225
# 228                           7.5  交通運輸    1  228      None
# 229                            一、  施工期間    3  229       228
# 230                            (一) 背景預測    4  230       229
# 231                          (二) 施工影響分析    4  231       229
# 232                            二、  營運期間    3  232       228
# 233                            三、  綜合評估    3  233       228
# 234                           7.6  文化資產    1  234      None
# 235                          一、  有形文化資產    3  235       234
# 236                          二、  無形文化資產    3  236       234
# 237                           7.7  安全評估    1  237      None
# 238           7.7.1  液化天然氣接收站設計規劃 及營運安全    2  238       237
# 239                     一、  液化天然氣儲槽設計規劃    3  239       238

# %%
df.iloc[240:300]
# Out:
#                                          tit  lev   id parent_id
# 240                       二、  液化天然氣接收站營運安全評估    3  240       238
# 241                            (一) 接收站儲槽選址規劃    4  241       240
# 242                       (二) 國際液化天然氣 災害案例整理    4  242       240
# 243                              7.7.2  評估方法    2  243       237
# 244                         7.7.3  危害辨識及事件列舉    2  244       237
# 245                       一、  對人員、船舶及公共設施的危害    3  245       244
# 246                                 (一) 火災危害    4  246       245
# 247                                 (二) 爆炸危害    4  247       245
# 248                           (三) 快速相變 (RPT)    4  248       245
# 249                                 (四) 低溫破壞    4  249       245
# 250                                (五) 中毒、窒息    4  250       245
# 251                               二、  量化事件列舉    3  251       244
# 252                              7.7.4  成果分析    2  252       237
# 253                               一、  模式輸入條件    3  253       252
# 254                                 二、  風險分析    3  254       252
# 255                              (一) 個體風險等高線    4  255       254
# 256                                 (二) 社會風險    4  256       254
# 257                                    1. 荷蘭    5  257       256
# 258                             2. 香港  (英國 )    5  258       256
# 259    (一) 不可接受的風險區域。在本計畫中指高風險區域。在這個區域，除非特殊情    4  259       254
# 260     (二) 允許的風險區域。在本計畫中指中度風險區域。在這個區域內必須滿足以    4  260       254
# 261                  1. 在當前的技術條件下，進一步降低風險不可行    5  261       260
# 262               2. 降低風險所需的成本遠遠大於降低風險所獲得的效益    5  262       260
# 263    (三) 廣泛可接受的風險區域。在本計畫中指低風險區域。在這個區域，剩餘風險    4  263       254
# 264                          三、  本計畫安全評估分析結果    3  264       252
# 265                       7.7.5  場(廠)區安全維護措施    2  265       237
# 266           一、  工作人員定期針對各設備及相關安全閥進行定期巡迴檢查。    3  266       265
# 267             二、  液化天然氣接收站內明確嚴禁煙火，如煙頭、靜電等。    3  267       265
# 268                    三、  工作人員該穿戴防靜電工作服和鞋子。    3  268       265
# 269                    四、  液化天然氣接收站安全及監控管理措施    3  269       265
# 270                     五、  液化天然氣接收站穩定供氣配套措施    3  270       265
# 271                 六、  執行液化天然氣洩漏監控措施，控管逸散情形    3  271       265
# 272  七、  台中發電廠複循環機組部份設有天 然氣洩漏偵測系統並設有專用之天然氣洩漏    3  272       265
# 273                              7.8  健康風險評估    1  273      None

# %%
fname=fnames[0].replace('.pdf','.csv')
a=read_csv(fname)
a
# Out:
#       id                              tit  lev  parent_id
# 0      0                     7.1  物理及化學環境    1        NaN
# 1      1                      7.1.1 地形及地質    2        0.0
# 2      2                           1.土壤改良    5        1.0
# 3      3                      2.基礎型式選擇或處理    5        1.0
# 4      4                         3.管線型式選擇    5        1.0
# ..   ...                              ...  ...        ...
# 256  256                   1.第一個條件是有漏氣現象；    5      255.0
# 257  257  2.第二個條件是漏出氣體被收集於密閉物體或場所中，無法溢散至大    5      255.0
# 258  258  3.第三個條件是有火花產生，因而造成火災或爆炸，或人員進入高濃    5      255.0
# 259  259                       (二) 減輕影響說明    4      254.0
# 260  260                       7.8 健康風險評估    1        NaN
#
# [261 rows x 4 columns]
